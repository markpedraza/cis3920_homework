# %% [markdown]
# # [3920] Homework 3 - KNN
# Data file:
# * https://raw.githubusercontent.com/vjavaly/Baruch-CIS-3920/main/data/credit_card_churners_2_10k.csv

# %% [markdown]
# ## Homework Submission Rules (for all homework assignments)
# * Homework is due by 2:30 PM on the due date
#   * No late submission will be accepted
# * You must submit a cleanly executed notebook (*.ipynb)
#   * Verify that you are submitting the correct homework file
# * Homework file naming convention
#   * LastName_FirstName_HwX.ipynb  [Replace X with the homework #]
#     * 1 point deducted for submitting homework not complying with naming convention
# * Before submission, execute "Kernel -> Restart Kernel and Run All Cells"
#   * 1 point deducted for not submitting a cleanly executed notebook

# %% [markdown]
# ## Homework 3 Requirements
# * Load data
# * Identify missing values and use SimpleImputer to replace missing values
# * Ordinal Encode independent variables: 'Education_Level', 'Income_Category' and 'Card_Category'
# * Dummy (one-hot) encode independent variables: 'Gender' and 'Marital_Status'
# * Label encode dependent variable: 'Attrition_Flag'
# * Separate independent and dependent variables
# * Standardize independent variables
# * Split data into training and test sets
# * Train KNeighborsClassifier (with default hyperparameters)
# * Calculate accuracy for KNeighborsClassifier (with default hyperparameters)
# * Re-train KNeighborsClassifier (change n_neighbors hyperparameter and at least one other hyperparameter)
#   * NOTE: The objective of changing these hyperparameters is to improve model accuracy
#     * If you used hyperparameter random_state in your initial model training, do NOT change this value during model retrainings
#     * Do NOT re-split training and test sets during model retrainings
# * Calculate accuracy for re-trained KNeighborsClassifier (with updated hyperparameters)

# %%
from datetime import datetime
print(f'Run time: {datetime.now().strftime("%D %T")}')
# Out:
# Run time: 06/10/25 20:40:56

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/vjavaly/Baruch-CIS-3920/main/data/credit_card_churners_2_10k.csv', index_col='CLIENTNUM')

# %% [markdown]
# ### Examine data

# %%
# Display first few rows of dataframe
df.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 718759833  Existing Customer          44.0      F                2
# 719084358  Attrited Customer          55.0      F                1
# 772643058  Existing Customer          58.0      F                3
# 718078008  Existing Customer          40.0      M                2
# 715479483  Existing Customer          35.0      M                2
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 718759833     High_School        Married             NaN        Silver
# 719084358         College        Married      Below_$40K          Blue
# 772643058         College        Married      Below_$40K          Blue
# 718078008         College       Divorced       $40K-$80K          Blue
# 715479483         College        Married      $80K-$120K          Blue
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 718759833              35                         4                       3
# 719084358              46                         6                       4
# 772643058              48                         6                       2
# 718078008              36                         3                       2
# 715479483              36                         5                       2
#
#            Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# CLIENTNUM
# 718759833                      2       32643.0                    0
# 719084358                      3        4232.0                    0
# 772643058                      3        2800.0                 1834
# 718078008                      1       20304.0                    0
# 715479483                      4       15279.0                 1496
#
#            Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM
# 718759833          32643.0                 1.300             1058
# 719084358           4232.0                 0.878             2312
# 772643058            966.0                 0.615             1571
# 718078008          20304.0                 0.809             7494
# 715479483          13783.0                 0.997             2079
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# CLIENTNUM
# 718759833              24                2.429                  0.000
# 719084358              37                0.609                  0.000
# 772643058              36                0.636                  0.655
# 718078008              85                0.667                  0.000
# 715479483              57                0.425                  0.098

# %% [markdown]
# ### Prepare data for model training

# %% [markdown]
# #### Use the SimpleImputer to replace missing values

# %%
# Check for missing values
df.isna().sum()
# Out:
# Attrition_Flag                 0
# Customer_Age                 501
# Gender                         0
# Dependent_count                0
# Education_Level                0
# Marital_Status                 0
# Income_Category             1101
# Card_Category                  0
# Months_on_book                 0
# Total_Relationship_Count       0
# Months_Inactive_12_mon         0
# Contacts_Count_12_mon          0
# Credit_Limit                   0
# Total_Revolving_Bal            0
# Avg_Open_To_Buy                0
# Total_Amt_Chng_Q4_Q1           0
# Total_Trans_Amt                0
# Total_Trans_Ct                 0
# Total_Ct_Chng_Q4_Q1            0
# Avg_Utilization_Ratio          0
# dtype: int64

# %%
# Create imputers
imputer_mean = SimpleImputer(strategy='mean')
imputer_freq = SimpleImputer(strategy='most_frequent')

# Apply mean imputer to Customer_Age
df['Customer_Age'] = imputer_mean.fit_transform(df[['Customer_Age']])

# Apply most frequent imputer to Income_Category
df['Income_Category'] = imputer_freq.fit_transform(df[['Income_Category']]).ravel()

# %%
# Display first few rows of updated dataframe
df.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 718759833  Existing Customer          44.0      F                2
# 719084358  Attrited Customer          55.0      F                1
# 772643058  Existing Customer          58.0      F                3
# 718078008  Existing Customer          40.0      M                2
# 715479483  Existing Customer          35.0      M                2
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 718759833     High_School        Married      Below_$40K        Silver
# 719084358         College        Married      Below_$40K          Blue
# 772643058         College        Married      Below_$40K          Blue
# 718078008         College       Divorced       $40K-$80K          Blue
# 715479483         College        Married      $80K-$120K          Blue
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 718759833              35                         4                       3
# 719084358              46                         6                       4
# 772643058              48                         6                       2
# 718078008              36                         3                       2
# 715479483              36                         5                       2
#
#            Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# CLIENTNUM
# 718759833                      2       32643.0                    0
# 719084358                      3        4232.0                    0
# 772643058                      3        2800.0                 1834
# 718078008                      1       20304.0                    0
# 715479483                      4       15279.0                 1496
#
#            Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM
# 718759833          32643.0                 1.300             1058
# 719084358           4232.0                 0.878             2312
# 772643058            966.0                 0.615             1571
# 718078008          20304.0                 0.809             7494
# 715479483          13783.0                 0.997             2079
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# CLIENTNUM
# 718759833              24                2.429                  0.000
# 719084358              37                0.609                  0.000
# 772643058              36                0.636                  0.655
# 718078008              85                0.667                  0.000
# 715479483              57                0.425                  0.098

# %% [markdown]
# #### Check for missing values again

# %%
df.isna().sum()
# Out:
# Attrition_Flag              0
# Customer_Age                0
# Gender                      0
# Dependent_count             0
# Education_Level             0
# Marital_Status              0
# Income_Category             0
# Card_Category               0
# Months_on_book              0
# Total_Relationship_Count    0
# Months_Inactive_12_mon      0
# Contacts_Count_12_mon       0
# Credit_Limit                0
# Total_Revolving_Bal         0
# Avg_Open_To_Buy             0
# Total_Amt_Chng_Q4_Q1        0
# Total_Trans_Amt             0
# Total_Trans_Ct              0
# Total_Ct_Chng_Q4_Q1         0
# Avg_Utilization_Ratio       0
# dtype: int64

# %% [markdown]
# #### Ordinal Encode Education_Level, Income_Category and Card_Category

# %%
# Ordinal encode column: Education_Level

# %%
oe_education = OrdinalEncoder(categories=[['High_School', 'College', 'Post-Graduate']])
df['Education_Level'] = oe_education.fit_transform(df[['Education_Level']])

# %%
# Ordinal encode column: Income_Category

# %%
oe_income = OrdinalEncoder(categories=[['Below_$40K', '$40K-$80K', '$80K-$120K', 'Above_$120K']])
df['Income_Category'] = oe_income.fit_transform(df[['Income_Category']])

# %%
# Ordinal encode column: Card_Category

# %%
oe_card = OrdinalEncoder(categories=[['Blue', 'Silver', 'Gold', 'Platinum']])
df['Card_Category'] = oe_card.fit_transform(df[['Card_Category']])

# %%
# Display first few rows of updated dataframe
df.head(10)
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 718759833  Existing Customer     44.000000      F                2
# 719084358  Attrited Customer     55.000000      F                1
# 772643058  Existing Customer     58.000000      F                3
# 718078008  Existing Customer     40.000000      M                2
# 715479483  Existing Customer     35.000000      M                2
# 779070033  Existing Customer     63.000000      F                0
# 714046608  Existing Customer     46.351616      M                0
# 708281433  Existing Customer     57.000000      F                2
# 711613308  Attrited Customer     58.000000      M                2
# 787565433  Existing Customer     46.351616      M                2
#
#            Education_Level Marital_Status  Income_Category  Card_Category  \
# CLIENTNUM
# 718759833              0.0        Married              0.0            1.0
# 719084358              1.0        Married              0.0            0.0
# 772643058              1.0        Married              0.0            0.0
# 718078008              1.0       Divorced              1.0            0.0
# 715479483              1.0        Married              2.0            0.0
# 779070033              1.0         Single              0.0            0.0
# 714046608              2.0        Married              1.0            0.0
# 708281433              1.0        Married              0.0            0.0
# 711613308              0.0         Single              1.0            0.0
# 787565433              2.0        Married              2.0            0.0
#
#            Months_on_book  Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 718759833              35                         4                       3
# 719084358              46                         6                       4
# 772643058              48                         6                       2
# 718078008              36                         3                       2
# 715479483              36                         5                       2
# 779070033              44                         3                       4
# 714046608              39                         5                       6
# 708281433              36                         5                       1
# 711613308              48                         2                       1
# 787565433              43                         4                       2
#
#            Contacts_Count_12_mon  Credit_Limit  Total_Revolving_Bal  \
# CLIENTNUM
# 718759833                      2       32643.0                    0
# 719084358                      3        4232.0                    0
# 772643058                      3        2800.0                 1834
# 718078008                      1       20304.0                    0
# 715479483                      4       15279.0                 1496
# 779070033                      2        1938.0                    0
# 714046608                      3       19719.0                 1395
# 708281433                      3        1438.3                    0
# 711613308                      2        2236.0                  710
# 787565433                      4        4039.0                 1397
#
#            Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM
# 718759833          32643.0                 1.300             1058
# 719084358           4232.0                 0.878             2312
# 772643058            966.0                 0.615             1571
# 718078008          20304.0                 0.809             7494
# 715479483          13783.0                 0.997             2079
# 779070033           1938.0                 0.536             3974
# 714046608          18324.0                 0.565             3572
# 708281433           1438.3                 0.565             3848
# 711613308           1526.0                 0.434             2562
# 787565433           2642.0                 0.396             1494
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio
# CLIENTNUM
# 718759833              24                2.429                  0.000
# 719084358              37                0.609                  0.000
# 772643058              36                0.636                  0.655
# 718078008              85                0.667                  0.000
# 715479483              57                0.425                  0.098
# 779070033              56                0.931                  0.000
# 714046608              73                0.738                  0.071
# 708281433              75                0.705                  0.000
# 711613308              38                0.462                  0.318
# 787565433              36                0.286                  0.346

# %% [markdown]
# #### Dummy (one-hot) encode Gender and Marital_Status

# %%
# Dummy (one-hot) encode column: Gender
df = pd.get_dummies(df, columns=['Gender'])

# %%
# Dummy (one-hot) encode column: Marital_Status
df = pd.get_dummies(df, columns=['Marital_Status'])

# %%
# Display first few rows of updated dataframe
df.head(10)
# Out:
#               Attrition_Flag  Customer_Age  Dependent_count  Education_Level  \
# CLIENTNUM
# 718759833  Existing Customer     44.000000                2              0.0
# 719084358  Attrited Customer     55.000000                1              1.0
# 772643058  Existing Customer     58.000000                3              1.0
# 718078008  Existing Customer     40.000000                2              1.0
# 715479483  Existing Customer     35.000000                2              1.0
# 779070033  Existing Customer     63.000000                0              1.0
# 714046608  Existing Customer     46.351616                0              2.0
# 708281433  Existing Customer     57.000000                2              1.0
# 711613308  Attrited Customer     58.000000                2              0.0
# 787565433  Existing Customer     46.351616                2              2.0
#
#            Income_Category  Card_Category  Months_on_book  \
# CLIENTNUM
# 718759833              0.0            1.0              35
# 719084358              0.0            0.0              46
# 772643058              0.0            0.0              48
# 718078008              1.0            0.0              36
# 715479483              2.0            0.0              36
# 779070033              0.0            0.0              44
# 714046608              1.0            0.0              39
# 708281433              0.0            0.0              36
# 711613308              1.0            0.0              48
# 787565433              2.0            0.0              43
#
#            Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 718759833                         4                       3
# 719084358                         6                       4
# 772643058                         6                       2
# 718078008                         3                       2
# 715479483                         5                       2
# 779070033                         3                       4
# 714046608                         5                       6
# 708281433                         5                       1
# 711613308                         2                       1
# 787565433                         4                       2
#
#            Contacts_Count_12_mon  ...  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM                         ...
# 718759833                      2  ...                 1.300             1058
# 719084358                      3  ...                 0.878             2312
# 772643058                      3  ...                 0.615             1571
# 718078008                      1  ...                 0.809             7494
# 715479483                      4  ...                 0.997             2079
# 779070033                      2  ...                 0.536             3974
# 714046608                      3  ...                 0.565             3572
# 708281433                      3  ...                 0.565             3848
# 711613308                      2  ...                 0.434             2562
# 787565433                      4  ...                 0.396             1494
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# CLIENTNUM
# 718759833              24                2.429                  0.000
# 719084358              37                0.609                  0.000
# 772643058              36                0.636                  0.655
# 718078008              85                0.667                  0.000
# 715479483              57                0.425                  0.098
# 779070033              56                0.931                  0.000
# 714046608              73                0.738                  0.071
# 708281433              75                0.705                  0.000
# 711613308              38                0.462                  0.318
# 787565433              36                0.286                  0.346
#
#            Gender_F  Gender_M  Marital_Status_Divorced  \
# CLIENTNUM
# 718759833      True     False                    False
# 719084358      True     False                    False
# 772643058      True     False                    False
# 718078008     False      True                     True
# 715479483     False      True                    False
# 779070033      True     False                    False
# 714046608     False      True                    False
# 708281433      True     False                    False
# 711613308     False      True                    False
# 787565433     False      True                    False
#
#            Marital_Status_Married  Marital_Status_Single
# CLIENTNUM
# 718759833                    True                  False
# 719084358                    True                  False
# 772643058                    True                  False
# 718078008                   False                  False
# 715479483                    True                  False
# 779070033                   False                   True
# 714046608                    True                  False
# 708281433                    True                  False
# 711613308                   False                   True
# 787565433                    True                  False
#
# [10 rows x 23 columns]

# %% [markdown]
# #### Label encode Attrition_Flag (target)

# %%
# Label encode target: Attrition_Flag
le = LabelEncoder()
df['Attrition_Flag'] = le.fit_transform(df['Attrition_Flag'])

# %%
# Display first few rows of updated dataframe
df.head()
# Out:
#            Attrition_Flag  Customer_Age  Dependent_count  Education_Level  \
# CLIENTNUM
# 718759833               1          44.0                2              0.0
# 719084358               0          55.0                1              1.0
# 772643058               1          58.0                3              1.0
# 718078008               1          40.0                2              1.0
# 715479483               1          35.0                2              1.0
#
#            Income_Category  Card_Category  Months_on_book  \
# CLIENTNUM
# 718759833              0.0            1.0              35
# 719084358              0.0            0.0              46
# 772643058              0.0            0.0              48
# 718078008              1.0            0.0              36
# 715479483              2.0            0.0              36
#
#            Total_Relationship_Count  Months_Inactive_12_mon  \
# CLIENTNUM
# 718759833                         4                       3
# 719084358                         6                       4
# 772643058                         6                       2
# 718078008                         3                       2
# 715479483                         5                       2
#
#            Contacts_Count_12_mon  ...  Total_Amt_Chng_Q4_Q1  Total_Trans_Amt  \
# CLIENTNUM                         ...
# 718759833                      2  ...                 1.300             1058
# 719084358                      3  ...                 0.878             2312
# 772643058                      3  ...                 0.615             1571
# 718078008                      1  ...                 0.809             7494
# 715479483                      4  ...                 0.997             2079
#
#            Total_Trans_Ct  Total_Ct_Chng_Q4_Q1  Avg_Utilization_Ratio  \
# CLIENTNUM
# 718759833              24                2.429                  0.000
# 719084358              37                0.609                  0.000
# 772643058              36                0.636                  0.655
# 718078008              85                0.667                  0.000
# 715479483              57                0.425                  0.098
#
#            Gender_F  Gender_M  Marital_Status_Divorced  \
# CLIENTNUM
# 718759833      True     False                    False
# 719084358      True     False                    False
# 772643058      True     False                    False
# 718078008     False      True                     True
# 715479483     False      True                    False
#
#            Marital_Status_Married  Marital_Status_Single
# CLIENTNUM
# 718759833                    True                  False
# 719084358                    True                  False
# 772643058                    True                  False
# 718078008                   False                  False
# 715479483                    True                  False
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Separate independent and dependent variables
# * Independent variables: All remaining variables except Attrition_Flag
# * Dependent variable: Attrition_Flag

# %%
Y = df["Attrition_Flag"]
X = df.drop("Attrition_Flag", axis=1)

# %% [markdown]
# ### Standardize independent variables

# %%
min_max_scaler = StandardScaler()
X = pd.DataFrame(min_max_scaler.fit_transform(X), columns=X.columns)

# %% [markdown]
# ### Split data into training and test sets

# %%
x_test, x_train, y_test, y_train = train_test_split(X, Y, stratify=Y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Train KNeighborsClassifier (with default hyperparameters)

# %%
knn = KNeighborsClassifier()
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'weights': 'uniform'}

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ### Evaluate performance for KNeighborsClassifier (with default hyperparameters)

# %%
# Predict using the test set
y_pred = knn.predict(x_test)

# %%
# Print model accuracy score
accuracy_score_1 = accuracy_score(y_test, y_pred)
print(f"Accuracy = {round((accuracy_score_1 * 100), 4)}%")
# Out:
# Accuracy = 88.4%

# %% [markdown]
# ### Train KNeighborsClassifier (change n_neighbors hyperparameter and at least one other hyperparameter)
# NOTE: The objective of changing these hyperparameters is to improve model accuracy

# %%
knn = KNeighborsClassifier(n_neighbors=10, metric='euclidean')
knn.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'euclidean',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 10,
#  'p': 2,
#  'weights': 'uniform'}

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=10)

# %% [markdown]
# ### Evaluate performance for KNeighborsClassifier (with updated hyperparameters)

# %%
# Predict using the test set
y_pred = knn.predict(x_test)

# %%
# Print model accuracy score
accuracy_score_1 = accuracy_score(y_test, y_pred)
print(f"Accuracy = {round((accuracy_score_1 * 100), 4)}%")
# Out:
# Accuracy = 88.75%
